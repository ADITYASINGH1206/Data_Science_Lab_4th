# %%
import pandas as pd
import requests

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJkMmRkNjU0ZmFiOTU2Zjk0ZDRlODA1NTg0OGJlYzg1YyIsIm5iZiI6MTc2ODg4NTAxMy42NDcsInN1YiI6IjY5NmYwYjE1Y2YzY2JkMjBiNmRmMGJlMSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.WsEbv3ydfM8QyLKXK4vyjTFAWPUbbabyao19317bNqA"
}

response = requests.get(url, headers=headers)

#print(response.text)

# %%
response.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
#response.json()

# %%
response.json()['results'] #fetch only results key values that gives me a list in which there are various dictionaries
# Out:
# [{'adult': False,
#   'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 28.8668,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 29558},
#  {'adult': False,
#   'backdrop_path': '/tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %%
# now this list needs to convert in dataframes and pass the list in this dataframe
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path         genre_ids      id  \
# 0   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]     278
# 1   False  /tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg          [18, 80]     238
# 2   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]     240
# 3   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]     424
# 4   False  /w4bTBXcqXc2TUyS5Fc4h67uWbPn.jpg              [18]     389
# 5   False  /ukfI9QkU1aIhOhKXYWE9n3z1mFR.jpg   [16, 10751, 14]     129
# 6   False  /cfT29Im5VDvjE0RpyKOSdCKZal7.jpg  [18, 28, 80, 53]     155
# 7   False  /zQDFHYNVVVp9OAYSixYAG1SyX1l.jpg   [35, 18, 10749]   19404
# 8   False  /lgJlu0Fp1mdTaFEeaQJ7DskhSOr.jpg      [14, 18, 80]     497
# 9   False  /hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg      [35, 53, 18]  496243
# 10  False  /2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg      [12, 14, 28]     122
# 11  False  /96hiUXEuYsu4tcnvlaY8tEMFM0m.jpg      [53, 80, 35]     680
# ...

# %%
pd.DataFrame(response.json()['results']).head(2)
# Out:
#    adult                     backdrop_path genre_ids   id original_language  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg  [18, 80]  278                en
# 1  False  /tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg  [18, 80]  238                en
#
#              original_title  \
# 0  The Shawshank Redemption
# 1             The Godfather
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     28.8668
# 1  Spanning the years 1945 to 1955, a chronicle o...     35.7668
#
#                         poster_path release_date                     title  \
# 0  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23  The Shawshank Redemption
# 1  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
#
#    video  vote_average  vote_count
# 0  False         8.700       29558
# 1  False         8.686       22317

# %%
# but it is giving me all the columns but needs some specific coloumns only
df = pd.DataFrame(response.json()['results'])[['id', 'title', 'release_date', 'overview', 'popularity', 'vote_average', 'vote_count']]

# %%
df.head()
# Out:
#     id                     title release_date  \
# 0  278  The Shawshank Redemption   1994-09-23
# 1  238             The Godfather   1972-03-14
# 2  240     The Godfather Part II   1974-12-20
# 3  424          Schindler's List   1993-12-15
# 4  389              12 Angry Men   1957-04-10
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     28.8668
# 1  Spanning the years 1945 to 1955, a chronicle o...     35.7668
# 2  In the continuing saga of the Corleone crime f...     19.6783
# 3  The true story of how businessman Oskar Schind...     13.8958
# 4  The defense and the prosecution have rested an...     11.0349
#
#    vote_average  vote_count
# 0         8.700       29558
# 1         8.686       22317
# 2         8.570       13495
# 3         8.565       17009
# 4         8.552        9664

# %%
# now we need to run this code in a loop
# this loop will run for 531 times i.e., the no. of pages
# after fetching data from each page it should append the data 
#finally we have complete dataset
# to store this first we needs to create an emplty dataframe
df = pd.DataFrame()  # empty dataframe

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests
import pandas as pd

df = pd.DataFrame()

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJkMmRkNjU0ZmFiOTU2Zjk0ZDRlODA1NTg0OGJlYzg1YyIsIm5iZiI6MTc2ODg4NTAxMy42NDcsInN1YiI6IjY5NmYwYjE1Y2YzY2JkMjBiNmRmMGJlMSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.WsEbv3ydfM8QyLKXK4vyjTFAWPUbbabyao19317bNqA"
}

for i in range(1, 100):  # Pages 1 to 531
    url = f"https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={i}"

    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        temp_df = pd.DataFrame(response.json()['results'])[
            ['id', 'title', 'release_date', 'overview',
             'popularity', 'vote_average', 'vote_count']
        ]

        df = pd.concat([df, temp_df], ignore_index=True)
    else:
        print(f"Failed at page {i}, status code: {response.status_code}")

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\.conda\envs\ml_tf\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# ...

# %%
df.shape
# Out:
# (1980, 7)

# %%
df.to_csv('toprated.csv')
